# %%
#!/usr/bin/env python3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
csv_file_path = '../Dataset/Summary/rf_scores.csv'  # Replace with your actual CSV file path
df = pd.read_csv(csv_file_path)
df = df.dropna()
# Make summary df
rf_summary_df = df.groupby(['folder', 'inner_folder', 'method'])['rf-score'].agg(['mean', 'std']).reset_index()

# Save the summary data to a new CSV file
rf_summary_csv_path = '../Dataset/Summary/rf_scores_summary.csv'  # Replace with your desired output file path
rf_summary_df.to_csv(rf_summary_csv_path, index=False)

# Unique folders
folders = df['folder'].unique()

# Iterate over each folder to create separate plots
for folder in folders:
    # Filter data for the current folder
    folder_data = df[df['folder'] == folder]

    # Create a bar plot for each inner folder/method combination
    plt.figure(figsize=(20, 12))
    sns.barplot(data=folder_data, x='inner_folder', y='rf-score', hue='method', ci=68, palette='tab10')

    # Plot adjustments
    plt.title(f'Average RF Scores in {folder}')
    plt.xlabel('Inner Folder')
    plt.ylabel('Average RF Score')
    plt.xticks(rotation=45)
    plt.legend(title='Method', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# /tmp/ipykernel_3486/3647172490.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='rf-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/3647172490.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='rf-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/3647172490.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='rf-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/3647172490.py:27: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='rf-score', hue='method', ci=68, palette='tab10')

# %%
#!/usr/bin/env python3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
csv_file_path = '../Dataset/Summary/triplet_scores.csv'  # Replace with your actual CSV file path
df = pd.read_csv(csv_file_path)
df = df.dropna()
# Compute mean and standard deviation for each combination of folder, inner_folder, and method
summary_df = df.groupby(['folder', 'inner_folder', 'method'])['triplet-score'].agg(['mean', 'std']).reset_index()

# Save the summary data to a new CSV file
summary_csv_path = '../Dataset/Summary/triplet_scores_summary.csv'  # Replace with your desired output file path
summary_df.to_csv(summary_csv_path, index=False)

# Unique folders
folders = df['folder'].unique()

# Iterate over each folder to create separate plots
for folder in folders:
    # Filter data for the current folder
    folder_data = df[df['folder'] == folder]

    # Create a bar plot for each inner folder/method combination
    plt.figure(figsize=(16, 12))
    # sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', errorbar='sd', palette='tab10')
    sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', ci=68, palette='tab10')

    # Plot adjustments
    plt.title(f'Average Triplet Scores in {folder}')
    plt.xlabel('Inner Folder')
    plt.ylabel('Average Triplet Score')
    plt.xticks(rotation=45)
    plt.legend(title='Method', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# /tmp/ipykernel_3486/237990451.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/237990451.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/237990451.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', ci=68, palette='tab10')
# /tmp/ipykernel_3486/237990451.py:28: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.barplot(data=folder_data, x='inner_folder', y='triplet-score', hue='method', ci=68, palette='tab10')

# %%
#QuartetScores

#!/usr/bin/env python3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
csv_file_path = '../Dataset/Summary/quartet_scores.csv'  # Update to quartet scores file path
df = pd.read_csv(csv_file_path)
# print(df.shape)
# print(df.head())
df = df.dropna()
# print(df.shape)
# print(df.head())
df['quartet_score'] = df['quartet_score'].astype(float)
# Compute mean and standard deviation for each combination of folder, inner_folder, and method
summary_df = df.groupby(['folder', 'inner_folder', 'method'])['quartet_score'].agg(['mean', 'std']).reset_index()  # Update column name

# Save the summary data to a new CSV file
summary_csv_path = '../Dataset/Summary/quartet_scores_summary.csv'  # Update to quartet summary file path
summary_df.to_csv(summary_csv_path, index=False)
#drop row with nan



# Unique folders
folders = df['folder'].unique()

# Iterate over each folder to create separate plots
for folder in folders:
    # Filter data for the current folder
    folder_data = df[df['folder'] == folder]

    # Create a bar plot for each inner folder/method combination
    plt.figure(figsize=(16, 12))
    sns.barplot(data=folder_data, x='inner_folder', y='quartet_score', hue='method', ci=68, palette='tab10')  # Update y-axis label

    # Plot adjustments
    plt.title(f'Average Quartet Scores in {folder}')
    plt.xlabel('Inner Folder')
    plt.ylabel('Average Quartet Score')  # Update y-axis label
    plt.xticks(rotation=45)
    plt.legend(title='Method', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# (2240, 5)
#      folder                       inner_folder method  R  quartet_score
# 0  15-taxon  100gene-100bp/estimated-genetrees     MP  1         1183.0
# 1  15-taxon  100gene-100bp/estimated-genetrees     MV  1         1183.0
# 2  15-taxon  100gene-100bp/estimated-genetrees     OG  1         1183.0
# 3  15-taxon  100gene-100bp/estimated-genetrees     RD  1            NaN
# 4  15-taxon  100gene-100bp/estimated-genetrees   RAND  1         1112.0
# (2186, 5)
#      folder                       inner_folder method  R  quartet_score
# 0  15-taxon  100gene-100bp/estimated-genetrees     MP  1         1183.0
# 1  15-taxon  100gene-100bp/estimated-genetrees     MV  1         1183.0
# 2  15-taxon  100gene-100bp/estimated-genetrees     OG  1         1183.0
# 4  15-taxon  100gene-100bp/estimated-genetrees   RAND  1         1112.0
# 5  15-taxon  100gene-100bp/estimated-genetrees     MP  2         1157.0
# /tmp/ipykernel_3486/764753584.py:37: FutureWarning:
#
# ...
